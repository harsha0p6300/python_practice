# %%
#Read a *CSV file* and display the first 5 rows, last 5 rows, shape, and column names.
import pandas as pd
df=pd.read_csv('employees.csv')
print(df)
# Out:
#     Employee_ID Employee_Name Department       City  Salary Joining_Date
# 0          1001       Priya_1      Sales       Pune   52000   2022-08-02
# 1          1002       Meena_2         HR       Pune   41000   2020-05-16
# 2          1003        Riya_3      Sales      Delhi   62000   2022-10-17
# 3          1004       Rahul_4      Sales  Bangalore   49000   2019-03-07
# 4          1005        Isha_5      Sales      Delhi   47000   2021-10-31
# ..          ...           ...        ...        ...     ...          ...
# 95         1096      Meena_96         HR  Bangalore   91000   2024-03-10
# 96         1097      Rahul_97         HR       Pune   94000   2021-04-24
# 97         1098      Kavya_98         HR    Chennai   45000   2020-11-11
# 98         1099      Priya_99    Finance  Hyderabad   89000   2023-06-01
# 99         1100     Meena_100         HR     Mumbai   57000   2021-08-21
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    Employee_ID Employee_Name Department       City  Salary Joining_Date
# 0         1001       Priya_1      Sales       Pune   52000   2022-08-02
# 1         1002       Meena_2         HR       Pune   41000   2020-05-16
# 2         1003        Riya_3      Sales      Delhi   62000   2022-10-17
# 3         1004       Rahul_4      Sales  Bangalore   49000   2019-03-07
# 4         1005        Isha_5      Sales      Delhi   47000   2021-10-31

# %%
df.tail()
# Out:
#     Employee_ID Employee_Name Department       City  Salary Joining_Date
# 95         1096      Meena_96         HR  Bangalore   91000   2024-03-10
# 96         1097      Rahul_97         HR       Pune   94000   2021-04-24
# 97         1098      Kavya_98         HR    Chennai   45000   2020-11-11
# 98         1099      Priya_99    Finance  Hyderabad   89000   2023-06-01
# 99         1100     Meena_100         HR     Mumbai   57000   2021-08-21

# %%
df.shape
# Out:
# (100, 6)

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Employee_Name', 'Department', 'City', 'Salary',
#        'Joining_Date'],
#       dtype='object')

# %%
df[df['Department'].isin(['Sales','HR'])]
# Out:
#     Employee_ID Employee_Name Department       City  Salary Joining_Date
# 0          1001       Priya_1      Sales       Pune   52000   2022-08-02
# 1          1002       Meena_2         HR       Pune   41000   2020-05-16
# 2          1003        Riya_3      Sales      Delhi   62000   2022-10-17
# 3          1004       Rahul_4      Sales  Bangalore   49000   2019-03-07
# 4          1005        Isha_5      Sales      Delhi   47000   2021-10-31
# 6          1007       Arjun_7      Sales  Bangalore   79000   2022-04-21
# 8          1009      Vikram_9      Sales  Hyderabad   59000   2024-05-14
# 11         1012       Amit_12      Sales      Delhi   53000   2024-06-15
# 13         1014      Kiran_14      Sales       Pune   49000   2022-12-13
# 14         1015       Neha_15      Sales  Bangalore   90000   2023-05-03
# 16         1017      Pooja_17         HR    Chennai   57000   2023-09-05
# 17         1018      Arjun_18      Sales      Delhi   75000   2020-03-05
# ...

# %%
#4.Create a Pandas DataFrame and display employees whose salary is between ₹40,000 and ₹70,000.
df[df['Salary'].between(40000,70000)]
# Out:
#     Employee_ID Employee_Name Department       City  Salary Joining_Date
# 0          1001       Priya_1      Sales       Pune   52000   2022-08-02
# 1          1002       Meena_2         HR       Pune   41000   2020-05-16
# 2          1003        Riya_3      Sales      Delhi   62000   2022-10-17
# 3          1004       Rahul_4      Sales  Bangalore   49000   2019-03-07
# 4          1005        Isha_5      Sales      Delhi   47000   2021-10-31
# 5          1006        Riya_6    Finance  Bangalore   63000   2023-01-06
# 7          1008      Vikram_8         IT  Bangalore   48000   2021-05-15
# 8          1009      Vikram_9      Sales  Hyderabad   59000   2024-05-14
# 9          1010      Pooja_10         IT      Delhi   51000   2019-07-18
# 10         1011     Ananya_11    Finance      Delhi   42000   2023-07-11
# 11         1012       Amit_12      Sales      Delhi   53000   2024-06-15
# 12         1013       Isha_13         IT      Delhi   47000   2023-08-26
# ...

# %%
df['Tax']=df['Salary']*0.05
df
# Out:
#     Employee_ID Employee_Name Department       City  Salary Joining_Date  \
# 0          1001       Priya_1      Sales       Pune   52000   2022-08-02
# 1          1002       Meena_2         HR       Pune   41000   2020-05-16
# 2          1003        Riya_3      Sales      Delhi   62000   2022-10-17
# 3          1004       Rahul_4      Sales  Bangalore   49000   2019-03-07
# 4          1005        Isha_5      Sales      Delhi   47000   2021-10-31
# ..          ...           ...        ...        ...     ...          ...
# 95         1096      Meena_96         HR  Bangalore   91000   2024-03-10
# 96         1097      Rahul_97         HR       Pune   94000   2021-04-24
# 97         1098      Kavya_98         HR    Chennai   45000   2020-11-11
# 98         1099      Priya_99    Finance  Hyderabad   89000   2023-06-01
# 99         1100     Meena_100         HR     Mumbai   57000   2021-08-21
#
#        Tax
# 0   2600.0
# 1   2050.0
# 2   3100.0
# 3   2450.0
# 4   2350.0
# ..     ...
# ...

# %%
#Sort employees by salary (descending) and name (ascending)
df=df.sort_values(by=['Salary','Employee_Name'],ascending=[False,True])
print(df)
# Out:
#     Employee_ID Employee_Name Department       City  Salary Joining_Date  \
# 37         1038      Divya_38      Sales  Hyderabad   94000   2020-10-25
# 42         1043       Isha_43    Finance  Bangalore   94000   2021-12-16
# 72         1073      Manoj_73  Marketing    Chennai   94000   2022-04-10
# 62         1063      Rahul_63    Finance    Chennai   94000   2021-02-15
# 96         1097      Rahul_97         HR       Pune   94000   2021-04-24
# ..          ...           ...        ...        ...     ...          ...
# 1          1002       Meena_2         HR       Pune   41000   2020-05-16
# 68         1069     Nikhil_69      Sales  Bangalore   39000   2019-04-27
# 66         1067     Ananya_67         IT  Hyderabad   38000   2022-01-15
# 89         1090      Kiran_90         HR      Delhi   37000   2019-08-18
# 88         1089       Riya_89    Finance      Delhi   35000   2021-06-23
#
#        Tax
# 37  4700.0
# 42  4700.0
# 72  4700.0
# 62  4700.0
# 96  4700.0
# ..     ...
# ...
